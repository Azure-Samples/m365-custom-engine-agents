# %% [markdown]
# # Semantic Kernel Blog Writer Agent with Azure OpenAI
# This notebook demonstrates how to use Semantic Kernel with Azure OpenAI and declarative YAML to create an agent that writes a blog post about a given topic.

# %%
# Install required packages (uncomment if running interactively)
# !pip install semantic-kernel azure-identity pyyaml

# %% [markdown]
# ## Define the YAML Agent Specification
# The agent is defined using YAML, specifying its type, instructions, and input parameters.

# %%
import yaml

AGENT_YAML = '''
type: chat_completion_agent
name: BlogWriterAgent
description: An agent that generates blog posts about a given topic.
instructions: |
  Write a detailed blog post about {{$topic}}. The blog post should be approximately {{$length}} paragraphs long and cover key aspects of the topic.
model:
  id: gpt-4.1-mini
  options:
    temperature: 0.2
inputs:
  topic:
    description: The topic of the blog post.
    required: true
  length:
    description: The number of paragraphs in the blog post.
    required: true
    default: 5
template:
  format: semantic-kernel
'''

# Display the YAML for reference
print(yaml.safe_load(AGENT_YAML))
# Out:
# {'type': 'chat_completion_agent', 'name': 'BlogWriterAgent', 'description': 'An agent that generates blog posts about a given topic.', 'instructions': 'Write a detailed blog post about {{$topic}}. The blog post should be approximately {{$length}} paragraphs long and cover key aspects of the topic.\n', 'model': {'id': 'gpt-4.1-mini', 'options': {'temperature': 0.2}}, 'inputs': {'topic': {'description': 'The topic of the blog post.', 'required': True}, 'length': {'description': 'The number of paragraphs in the blog post.', 'required': True, 'default': 5}}, 'template': {'format': 'semantic-kernel'}}

# %% [markdown]
# ## Set Up Azure OpenAI Credentials
# You need to provide your Azure OpenAI endpoint and key. Replace the placeholders below with your actual values.

# %%
import os
from dotenv import load_dotenv

load_dotenv()

AZURE_OPENAI_ENDPOINT = os.getenv('AZURE_OPENAI_ENDPOINT', '<your-endpoint>')
AZURE_OPENAI_API_KEY = os.getenv('AZURE_OPENAI_API_KEY', '<your-key>')
AZURE_OPENAI_CHAT_DEPLOYMENT_NAME = os.getenv('AZURE_OPENAI_CHAT_DEPLOYMENT_NAME', '<your-deployment-id>')

# %% [markdown]
# ## Create and Run the Blog Writer Agent
# This cell creates the agent from the YAML spec and invokes it to write a blog post about a given topic.

# %%
from semantic_kernel import Kernel
from semantic_kernel.agents import AgentRegistry, ChatCompletionAgent, AzureResponsesAgent
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion, AzureOpenAISettings

# Create the Kernel and add the Azure OpenAI service (env vars will be picked up automatically)
# kernel = Kernel()
# kernel.add_service(AzureChatCompletion())

async def run_blog_writer(topic, length=5) -> str:
    agent_declaration = yaml.safe_load(AGENT_YAML)
    client = AzureResponsesAgent.create_client(
        # deployment_name="gpt-5-nano",
    )
    # Create the agent from YAML using the kernel and service
    # agent: AzureResponsesAgent = await AgentRegistry.create_from_yaml(
    #     yaml_str=AGENT_YAML, 
    #     client=client,
    #     # service=AzureChatCompletion()
    #     # kernel=kernel
    # )
    
    agent = AzureResponsesAgent(
        name=agent_declaration["name"],
        instructions=agent_declaration["instructions"],
        client=client,
        ai_model_id=agent_declaration["model"]["id"],
    )
    
    print(f"Using agent: {agent.name} with model: {agent.ai_model_id}")

    # Maintain conversation thread
    thread = None
    user_input = f"Write a blog post about {topic} that is {length} paragraphs long."
    response = await agent.get_response(
        messages=user_input,
        thread=thread,
        topic=topic,
        length=length
    )
    thread = response.thread
    return response.content

# Example usage
topic = "The role of AI Agents in BPMN"
length = 4

blog_article = await run_blog_writer(topic, length)

print("# Generated Blog Post:")
print(blog_article)
# Out:
# Using agent: BlogWriterAgent with model: gpt-4.1-mini
# # Generated Blog Post:
# **The Role of AI Agents in BPMN**
#
# Business Process Model and Notation (BPMN) has long been a cornerstone for organizations aiming to visualize, analyze, and optimize their business processes. As artificial intelligence continues to advance, the integration of AI agents into BPMN frameworks is transforming how businesses automate workflows and make intelligent decisions. AI agents, acting as autonomous software entities, can interpret BPMN diagrams, execute tasks, and adapt processes dynamically based on real-time data, thereby elevating the traditional BPMN approach from static documentation to proactive process management.
#
# One of the primary roles AI agents play in BPMN is enhancing process automation and efficiency. Unlike conventional automation tools that follow strict predefined rules, AI agents bring cognitive capabilities such as natural language understanding, machine learning, and predictive analytics. This enables the agents to handle complex decision points within BPMN models, such as exception management, resource allocation, and customer interactions. For instance, in a customer service process modeled in BPMN, AI agents can analyze incoming queries, categorize them, route them to appropriate human agents, or even provide automated responses, thereby significantly reducing response times and improving customer satisfaction.
#
# Moreover, AI agents facilitate continuous process improvement by leveraging real-time data and learning from historical outcomes. When embedded within BPMN workflows, these agents can monitor process performance metrics, identify bottlenecks, and recommend process refinements autonomously. This dynamic adaptation is especially valuable in rapidly changing business environments where flexibility and speed are crucial. Additionally, AI agents can simulate different scenarios within the BPMN framework to predict the impact of changes before implementation, enabling data-driven decisions that align with strategic objectives.
#
# Finally, the collaboration between human workers and AI agents in BPMN-driven processes fosters a more resilient and intelligent enterprise workflow. AI agents not only automate routine tasks but also support human decision-making by providing insights, suggestions, and risk assessments during process execution. This synergy enhances operational effectiveness while allowing human employees to focus on creativity and strategic activities. As AI technology continues to evolve, its role within BPMN will expand, offering greater possibilities for intelligent process automation, adaptive management, and ultimately, driving digital transformation initiatives across industries.

# %%
import yaml
from pydantic import BaseModel
from typing import List, Optional

class SEOAgentOutput(BaseModel):
    title: str
    meta_description: str
    slug: str
    h1: str
    h2s: List[str]
    revised_article: str
    improvements: List[str]
    seo_keywords: List[str]
    internal_links: List[str]
    external_links: List[str]
    readability_score: Optional[float]
    call_to_action: Optional[str]

SEO_AGENT_YAML = '''
type: chat_completion_agent
name: SEOOptimizerAgent
description: An agent that optimizes blog articles for SEO.
instructions: |
  Rewrite the following blog article to be SEO optimized. Use relevant keywords, improve readability, and ensure the content is engaging for search engines. Return a structured output containing:
    - title
    - meta description
    - slug
    - h1 and h2 headings
    - the revised article
    - a list of improvements
    - relevant SEO keywords
    - internal and external links
    - readability score
    - a call to action
  # Article
  {{$article}}
inputs:
  article:
    description: The original blog article to optimize.
    required: true
model:
  id: gpt-oss-120b
  options:
    temperature: 0.2
    response_format: SEOAgentOutput
template:
  format: semantic-kernel
'''

print(yaml.safe_load(SEO_AGENT_YAML))
# Out:
# {'type': 'chat_completion_agent', 'name': 'SEOOptimizerAgent', 'description': 'An agent that optimizes blog articles for SEO.', 'instructions': 'Rewrite the following blog article to be SEO optimized. Use relevant keywords, improve readability, and ensure the content is engaging for search engines. Return a structured output containing:\n  - title\n  - meta description\n  - slug\n  - h1 and h2 headings\n  - the revised article\n  - a list of improvements\n  - relevant SEO keywords\n  - internal and external links\n  - readability score\n  - a call to action\n# Article\n{{$article}}\n', 'inputs': {'article': {'description': 'The original blog article to optimize.', 'required': True}}, 'model': {'id': 'gpt-oss-120b', 'options': {'temperature': 0.2, 'response_format': 'SEOAgentOutput'}}, 'template': {'format': 'semantic-kernel'}}

# %%
import json
from semantic_kernel import Kernel
from semantic_kernel.agents import AgentRegistry, ChatCompletionAgent
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion, AzureChatPromptExecutionSettings
from semantic_kernel.functions import KernelArguments

from pydantic import ValidationError

# Create the Kernel and add the Azure OpenAI service (env vars will be picked up automatically)
kernel = Kernel()
kernel.add_service(AzureChatCompletion())

# Create execution settings with structured output
execution_settings = AzureChatPromptExecutionSettings()
execution_settings.response_format = SEOAgentOutput

# Pass these settings as arguments when creating the agent
arguments = KernelArguments(settings=execution_settings)

async def run_seo_optimizer_structured(article):
    # Create the SEO optimizer agent from YAML
    agent: ChatCompletionAgent = await AgentRegistry.create_from_yaml(
        SEO_AGENT_YAML, kernel=kernel, arguments=arguments
    )

    # Maintain conversation thread
    thread = None
    response = await agent.get_response(
        # messages=article,
        thread=thread,
        article=article
    )
    thread = response.thread
    print(response.model_dump())
    return response.message.content

# Example usage
seo_blog_article_structured = await run_seo_optimizer_structured(blog_article)

# Parse structured output
try:
    result = SEOAgentOutput.model_validate(json.loads(seo_blog_article_structured))
    print("\n\n# SEO Optimization Result:")
    print(json.dumps(result.model_dump(), indent=2))
    print("\n\n# SEO Optimized Blog Article:")
    print(result.revised_article)
except ValidationError as e:
    print("Error parsing structured output:", e)
    print("Raw response:", seo_blog_article_structured)
# Out:
# {'message': {'ai_model_id': 'gpt-5-mini', 'metadata': {'logprobs': None, 'id': 'chatcmpl-C1zzDNh7KlFNNrWyU1hgnDrrRmuuj', 'created': 1754592639, 'system_fingerprint': None, 'usage': {'prompt_tokens': 858, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'completion_tokens': 1712, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}}}, 'content_type': 'message', 'role': <AuthorRole.ASSISTANT: 'assistant'>, 'name': 'SEOOptimizerAgent', 'items': [{'ai_model_id': None, 'metadata': {}, 'content_type': 'text', 'text': '{"title":"How AI Agents Transform BPMN: Intelligent Workflows, Decisioning, and Process Mining","meta_description":"Discover how AI agents integrate with BPMN to create intelligent workflows—enhancing decisioning, automation, process mining, and governance for adaptive business processes.","slug":"ai-agents-bpmn-intelligent-workflows","h1":"How AI Agents Transform BPMN: Intelligent, Adaptive Workflows","h2s":["Why AI Agents Matter in BPMN","Intelligent Decisioning and Dynamic Routing","Conversational User Tasks and Automation","Monitoring, Optimization, and Process Mining","Governance, Architecture, and Model Lifecycle","Best Practices for Implementing AI Agents in BPMN","Future Trends: Adaptive, Explainable, and Resilient Processes"],"revised_article":"Business Process Model and Notation (BPMN) is the standard for modeling and orchestrating enterprise workflows. Today, integrating AI agents into BPMN is reshaping how organizations design, run, and continuously improve processes. AI agents—autonomous software components that perceive context, make decisions, and take actions—can be embedded in BPMN as enhanced service tasks, decision gateways, or event handlers to enable intelligent, context-aware workflows.\\n\\nWhy AI Agents Matter in BPMN\\nAI agents bring capabilities such as natural language understanding, computer vision, predictive analytics, and anomaly detection directly into process models. Instead of static, rule-based flows, processes become adaptive: agents interpret unstructured input, recommend the best next step, and trigger subprocesses or external APIs. This shift turns BPMN diagrams into living orchestrations where nodes can initiate dynamic behavior, improving throughput and resilience.\\n\\nIntelligent Decisioning and Dynamic Routing\\nOne of the most valuable roles for AI agents is intelligent decisioning and routing. Machine learning models or agent-based reasoning embedded in decision tasks can evaluate complex, probabilistic inputs—customer sentiment, fraud risk, supplier availability—and choose optimal paths. This approach extends or replaces traditional decision tables with predictive routing that reduces cycle time and improves outcomes. Agents can also apply business policies and escalate exceptions to human reviewers when uncertainty is high.\\n\\nConversational User Tasks and Automation\\nAI agents can serve as conversational intermediaries in user tasks. Chatbots and virtual assistants handle routine inquiries, collect structured data, and initiate automated subprocesses while escalating only complex cases to humans. This hybrid of automation and human-in-the-loop control increases efficiency and employee focus on strategic work. By annotating user-task nodes with agent activity logs, BPMN models keep process context and auditability intact.\\n\\nMonitoring, Optimization, and Process Mining\\nProcess-mining agents continuously ingest execution logs, detect bottlenecks, and recommend model changes. Reinforcement learning and predictive analytics enable agents to propose new variants or optimal task assignments. Anomaly-detection agents provide real-time alerts for deviations, and predictive agents forecast SLA breaches so teams can intervene proactively. To maintain trust, agents should emit explainable signals—annotated tasks, decision logs, and traceable metrics—so stakeholders can ve ...
#
#
# # SEO Optimization Result:
# {
#   "title": "How AI Agents Transform BPMN: Intelligent Workflows, Decisioning, and Process Mining",
#   "meta_description": "Discover how AI agents integrate with BPMN to create intelligent workflows\u2014enhancing decisioning, automation, process mining, and governance for adaptive business processes.",
#   "slug": "ai-agents-bpmn-intelligent-workflows",
#   "h1": "How AI Agents Transform BPMN: Intelligent, Adaptive Workflows",
#   "h2s": [
#     "Why AI Agents Matter in BPMN",
#     "Intelligent Decisioning and Dynamic Routing",
#     "Conversational User Tasks and Automation",
#     "Monitoring, Optimization, and Process Mining",
#     "Governance, Architecture, and Model Lifecycle",
#     "Best Practices for Implementing AI Agents in BPMN",
#     "Future Trends: Adaptive, Explainable, and Resilient Processes"
#   ],
#   "revised_article": "Business Process Model and Notation (BPMN) is the standard for modeling and orchestrating enterprise workflows. Today, integrating AI agents into BPMN is reshaping how organizations design, run, and continuously improve processes. AI agents\u2014autonomous software components that perceive context, make decisions, and take actions\u2014can be embedded in BPMN as enhanced service tasks, decision gateways, or event handlers to enable intelligent, context-aware workflows.\n\nWhy AI Agents Matter in BPMN\nAI agents bring capabilities such as natural language understanding, computer vision, predictive analytics, and anomaly detection directly into process models. Instead of static, rule-based flows, processes become adaptive: agents interpret unstructured input, recommend the best next step, and trigger subprocesses or external APIs. This shift turns BPMN diagrams into living orchestrations where nodes can initiate dynamic behavior, improving throughput and resilience.\n\nIntelligent Decisioning and Dynamic Routing\nOne of the most valuable roles for AI agents is intelligent decisioning and routing. Machine learning models or agent-based reasoning embedded in decision tasks can evaluate complex, probabilistic inputs\u2014customer sentiment, fraud risk, supplier availability\u2014and choose optimal paths. This approach extends or replaces traditional decision tables with predictive routing that reduces cycle time and improves outcomes. Agents can also apply business policies and escalate exceptions to human reviewers when uncertainty is high.\n\nConversational User Tasks and Automation\nAI agents can serve as conversational intermediaries in user tasks. Chatbots and virtual assistants handle routine inquiries, collect structured data, and initiate automated subprocesses while escalating only complex cases to humans. This hybrid of automation and human-in-the-loop control increases efficiency and employee focus on strategic work. By annotating user-task nodes with agent activity logs, BPMN models keep process context and auditability intact.\n\nMonitoring, Optimization, and Process Mining\nProcess-mining agents continuously ingest execution logs, detect bottlenecks, and recommend model changes. Reinforcement learning and predictive analytics enable agents to propose new variants or optimal task assignments. Anomaly-detection agents provide real-time alerts for deviations, and predictive agents forecast SLA breaches so teams can intervene proactively. To maintain trust, agents should emit explainable signals\u2014annotated tasks, decision logs, and traceable metrics\u2014so stakeholders can verify and govern automated decisions.\n\nGovernance, Architecture, and Model Lifecycle\nDeploying AI agents in BPMN requires careful architecture and governance. Key considerations include: defining clear interfaces between agents and BPMN elements, managing the model lifecycle (training, validation, monitoring, retraining), and implementing failover patterns to handle model uncertainty or degradation. Human-in-the-loop checkpoints are vital in high-risk domains like finance and healthcare. Audit trails, versioning, and compliance reporting must be built into both BPMN artifacts and agent outputs to satisfy regulatory requirements.\n\nBest Practices for Implementing AI Agents in BPMN\n- Map use cases: prioritize high-impact, repeatable processes for agent augmentation.\n- Define interfaces: create API and data contracts between BPMN tasks and agent services.\n- Monitor continuously: use process mining and telemetry to track model performance and process KPIs.\n- Ensure explainability: log decision rationale and present interpretable annotations in BPMN diagrams.\n- Plan governance: establish roles, retraining schedules, and rollback mechanisms.\n\nFuture Trends: Adaptive, Explainable, and Resilient Processes\nAs standards and tooling evolve, AI agents will make BPMN a platform for continuous, intelligent transformation. Expec ...
#   "improvements": [
#     "Added SEO-optimized title and meta description focused on primary keywords (AI agents, BPMN, intelligent workflows).",
#     "Organized content with clear H1 and multiple H2 headings to improve scannability and search relevance.",
#     "Simplified language and short paragraphs to improve readability and engagement.",
#     "Inserted actionable best practices and governance guidance to increase practical value and user intent match.",
#     "Included future trends and implementation guidance to target long-tail queries and decision-stage searches.",
#     "Added internal and external link suggestions to improve authority and navigation."
#   ],
#   "seo_keywords": [
#     "BPMN",
#     "AI agents",
#     "intelligent workflows",
#     "process automation",
#     "process mining",
#     "decisioning and routing",
#     "predictive analytics",
#     "anomaly detection",
#     "explainable AI",
#     "human-in-the-loop",
#     "model lifecycle",
#     "business process modeling",
#     "workflow orchestration"
#   ],
#   "internal_links": [
#     "/blog/bpmn-best-practices",
#     "/resources/process-mining-guide",
#     "/solutions/automation-governance"
#   ],
#   "external_links": [
#     "https://www.omg.org/spec/BPMN/",
#     "https://en.wikipedia.org/wiki/Business_Process_Model_and_Notation",
#     "https://www.celonis.com/what-is-process-mining/",
#     "https://www.darpa.mil/program/explainable-artificial-intelligence"
#   ],
#   "readability_score": 62.0,
#   "call_to_action": "Ready to modernize your BPMN workflows with AI agents? Contact our team for a free assessment and roadmap to intelligent process automation."
# }
#
#
# # SEO Optimized Blog Article:
# Business Process Model and Notation (BPMN) is the standard for modeling and orchestrating enterprise workflows. Today, integrating AI agents into BPMN is reshaping how organizations design, run, and continuously improve processes. AI agents—autonomous software components that perceive context, make decisions, and take actions—can be embedded in BPMN as enhanced service tasks, decision gateways, or event handlers to enable intelligent, context-aware workflows.
#
# Why AI Agents Matter in BPMN
# AI agents bring capabilities such as natural language understanding, computer vision, predictive analytics, and anomaly detection directly into process models. Instead of static, rule-based flows, processes become adaptive: agents interpret unstructured input, recommend the best next step, and trigger subprocesses or external APIs. This shift turns BPMN diagrams into living orchestrations where nodes can initiate dynamic behavior, improving throughput and resilience.
#
# Intelligent Decisioning and Dynamic Routing
# One of the most valuable roles for AI agents is intelligent decisioning and routing. Machine learning models or agent-based reasoning embedded in decision tasks can evaluate complex, probabilistic inputs—customer sentiment, fraud risk, supplier availability—and choose optimal paths. This approach extends or replaces traditional decision tables with predictive routing that reduces cycle time and improves outcomes. Agents can also apply business policies and escalate exceptions to human reviewers when uncertainty is high.
#
# Conversational User Tasks and Automation
# AI agents can serve as conversational intermediaries in user tasks. Chatbots and virtual assistants handle routine inquiries, collect structured data, and initiate automated subprocesses while escalating only complex cases to humans. This hybrid of automation and human-in-the-loop control increases efficiency and employee focus on strategic work. By annotating user-task nodes with agent activity logs, BPMN models keep process context and auditability intact.
#
# Monitoring, Optimization, and Process Mining
# Process-mining agents continuously ingest execution logs, detect bottlenecks, and recommend model changes. Reinforcement learning and predictive analytics enable agents to propose new variants or optimal task assignments. Anomaly-detection agents provide real-time alerts for deviations, and predictive agents forecast SLA breaches so teams can intervene proactively. To maintain trust, agents should emit explainable signals—annotated tasks, decision logs, and traceable metrics—so stakeholders can verify and govern automated decisions.
#
# Governance, Architecture, and Model Lifecycle
# Deploying AI agents in BPMN requires careful architecture and governance. Key considerations include: defining clear interfaces between agents and BPMN elements, managing the model lifecycle (training, validation, monitoring, retraining), and implementing failover patterns to handle model uncertainty or degradation. Human-in-the-loop checkpoints are vital in high-risk domains like finance and healthcare. Audit trails, versioning, and compliance reporting must be built into both BPMN artifacts and agent outputs to satisfy regulatory requirements.
#
# Best Practices for Implementing AI Agents in BPMN
# - Map use cases: prioritize high-impact, repeatable processes for agent augmentation.
# - Define interfaces: create API and data contracts between BPMN tasks and agent services.
# - Monitor continuously: use process mining and telemetry to track model performance and process KPIs.
# - Ensure explainability: log decision rationale and present interpretable annotations in BPMN diagrams.
# - Plan governance: establish roles, retraining schedules, and rollback mechanisms.
#
# Future Trends: Adaptive, Explainable, and Resilient Processes
# As standards and tooling evolve, AI agents will make BPMN a platform for continuous, intelligent transformation. Expect more out-of-the-box connectors, model governance frameworks, and native support for explainability in process tooling. Organizations that combine BPMN best practices with AI governance and human oversight will create adaptive, explainable, and resilient workflows that drive measurable business value.
#
# Integrating AI agents with BPMN unlocks smarter decisioning, scalable automation, and continuous process improvement. By focusing on secure interfaces, model governance, and explainability, teams can accelerate automation while maintaining trust and compliance.
